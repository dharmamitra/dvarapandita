# %%
from vectorizer_pali import Vectorizer

# %%
v = Vectorizer(
    "pli",
    "../test-data/pali/stemmed-tsv",
    input_extention=".tsv",
)
# Out:
# Vectorizer: 3 input files found
# Vectorizer: 3 processed files found
# ...

# %%
test_file = v.file_mngr.file_paths[0]

# %%
text = v.create_vectorfile(test_file)
# Out:
# NOW PROCESSING abhidhamma-ds-ds1--ds1.1_root-pli-ms.stemmed

# %%
text.words_df
# Out:
#      segmentId stemmed_text  weights  \
# 0    ds1.1:0.1      ▁dhamma      1.0
# 0    ds1.1:0.1          saṃ      1.0
# 0    ds1.1:0.1          gaṇ      1.0
# 0    ds1.1:0.1            ī      1.0
# 1    ds1.1:0.2         ▁tik      1.0
# ..         ...          ...      ...
# 90  ds1.1:66.1      ▁dhammā      1.0
# 91  ds1.1:66.2         ▁tik      1.0
# 91  ds1.1:66.2            a      1.0
# 91  ds1.1:66.2        mātik      1.0
# 91  ds1.1:66.2            ā      1.0
#
#                                               vectors  \
# 0   [0.49842602, 0.13939862, -0.18911129, 0.539696...
# 0   [-0.14652283, 0.16191465, -0.37120858, 0.23266...
# 0   [0.16878396, 0.4747072, -0.08584538, 0.2211898...
# 0   [-0.055903785, -0.06804281, -0.10822103, 0.200...
# 1   [0.0843615, 0.67192644, -0.4764215, -0.2324449...
# ..                                                ...
# 90  [-0.30500633, 0.21799731, -0.13967754, 0.23976...
# 91  [0.0843615, 0.67192644, -0.4764215, -0.2324449...
# ...

# %%
v.get_vector("saṃ")
# Out:
# array([-1.46522835e-01,  1.61914647e-01, -3.71208578e-01,  2.32662737e-01,
#         1.28685042e-01,  1.43076152e-01,  8.47836956e-02,  1.54346511e-01,
#         2.50115413e-02, -4.55733180e-01,  9.24507454e-02,  2.74314582e-02,
#        -2.34727990e-02,  4.59665120e-01, -3.58864248e-01,  1.83089003e-01,
#         3.65637809e-01,  1.62624091e-01,  2.20892236e-01,  1.90698337e-02,
#         4.80913706e-02,  2.41521806e-01, -1.24097668e-01,  1.41586781e-01,
#         3.77798438e-01,  1.74592808e-01,  4.93041575e-01, -3.07393372e-01,
#         4.64972662e-04,  1.09938934e-01, -2.17358582e-02, -9.33582857e-02,
#        -7.17080384e-02,  3.85592550e-01,  1.04259260e-01, -2.78290093e-01,
#        -3.06423277e-01, -7.99301732e-03, -2.74426699e-01,  2.38534600e-01,
#        -1.68077610e-02,  1.26068905e-01,  1.53628811e-01, -2.16042489e-01,
#         1.58352882e-01,  6.84290156e-02,  3.09069723e-01,  3.87939841e-01,
# ...
